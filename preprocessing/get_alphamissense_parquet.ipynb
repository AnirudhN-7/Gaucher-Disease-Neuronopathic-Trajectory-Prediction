# %%
from google.colab import drive
import duckdb

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#change the path as per where the dataset is saved
PROJECT_PATH = "/content/drive/MyDrive"

# %%
file_path = f"{PROJECT_PATH}/AlphaMissense_isoforms_hg38.tsv"

# %%
con = duckdb.connect()

# %%
parquet_path = "/content/drive/MyDrive/AlphaMissense.parquet"

con.execute(f"""
COPY(
    SELECT *
    FROM read_csv_auto('{file_path}', delim='\t')
)
TO '{parquet_path}'
(FORMAT PARQUET);
""")
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
